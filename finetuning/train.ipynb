# %%
pip install liger-kernel
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting liger-kernel
#   Downloading liger_kernel-0.6.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: torch>=2.1.2 in /opt/venv/lib/python3.10/site-packages (from liger-kernel) (2.9.0.dev20250821+rocm7.0.0.lw.git125803b7)
# Requirement already satisfied: triton>=2.3.1 in /opt/venv/lib/python3.10/site-packages (from liger-kernel) (3.4.0+rocm7.0.0.git56765e8c)
# Requirement already satisfied: filelock in /opt/venv/lib/python3.10/site-packages (from torch>=2.1.2->liger-kernel) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/venv/lib/python3.10/site-packages (from torch>=2.1.2->liger-kernel) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/venv/lib/python3.10/site-packages (from torch>=2.1.2->liger-kernel) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/venv/lib/python3.10/site-packages (from torch>=2.1.2->liger-kernel) (2.8.8)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.10/site-packages (from torch>=2.1.2->liger-kernel) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/venv/lib/python3.10/site-packages (from torch>=2.1.2->liger-kernel) (2025.3.0)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/venv/lib/python3.10/site-packages (from triton>=2.3.1->liger-kernel) (69.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.1.2->liger-kernel) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.10/site-packages (from jinja2->torch>=2.1.2->liger-kernel) (3.0.2)
# Downloading liger_kernel-0.6.3-py3-none-any.whl (210 kB)
# Installing collected packages: liger-kernel
# Successfully installed liger-kernel-0.6.3
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dataclasses import dataclass, field

from datasets import load_dataset
from transformers.models.auto.modeling_auto import AutoModelForCausalLM
from transformers.models.auto.tokenization_auto import AutoTokenizer
from trl import ModelConfig, SFTTrainer, TrlParser, SFTConfig
from accelerate.state import PartialState
import torch
# Out:
# /opt/venv/lib/python3.10/site-packages/torchao/utils.py:408: UserWarning: TORCH_VERSION_AT_LEAST_2_5 is deprecated and will be removed in torchao 0.14.0
#   warnings.warn(self.msg)

# %%
dataset = load_dataset("jupyter-agent/jupyter-agent-dataset", split="non_thinking")

cols = [
        "id",
        "edu_score",
        "files_used",
        "packages_used",
        "question",
        "answer",
        "kaggle_dataset_name",
        "executor_type",
        "original_notebook",
]

dataset = dataset.remove_columns(cols)
dataset = dataset.shuffle(seed=42)

eval_size = int(0.02 * len(dataset))
if eval_size < 1:
    eval_size = 1
train_size = len(dataset) - eval_size
train_dataset = dataset.select(range(train_size))
eval_dataset = dataset.select(range(train_size, len(dataset)))
# Out:
# Resolving data files:   0%|          | 0/103 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/103 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/103 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/103 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/67 [00:00<?, ?it/s]

# %%
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-Coder-30B-A3B-Instruct",attn_implementation="flash_attention_2",torch_dtype=torch.bfloat16)
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-Coder-30B-A3B-Instruct")
with (
        open("templates/qwen3_chat_non_thinking_template.jinja") as f
    ):  # original chat template of Qwen3-4B-Instruct-2507 with added generation tags for assistant_only_loss=True
        template = f.read()
tokenizer.chat_template = template

training_args = SFTConfig(
    eval_strategy="steps",
    eval_steps=500,
    eval_on_start=True,
    gradient_accumulation_steps=1,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant":False},
    logging_steps=1,
    logging_strategy="steps",
    lr_scheduler_type="cosine_with_min_lr",
    learning_rate=5e-06,
    neftune_noise_alpha=7,
    lr_scheduler_kwargs={"min_lr_rate":0.1},
    packing=False,
    max_length=32768,
    num_train_epochs=5,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    report_to="tensorboard",
    save_strategy="epoch",
    save_total_limit=10,
    seed=42,
    use_liger_kernel=True,
    warmup_ratio=0.03,
    assistant_only_loss=True,
)

trainer = SFTTrainer(
        model,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        args=training_args,
        processing_class=tokenizer,
    )

trainer.train()

trainer.save_model()
# Out:
# Loading checkpoint shards:   0%|          | 0/16 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='None' max='251810' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       None
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>1.108897</td>
#     </tr>
#   </tbody>
# </table><p>
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[3], line 44
#       9 training_args = SFTConfig(
#      10     eval_strategy="steps",
#      11     eval_steps=500,
#    (...)
#      33     assistant_only_loss=True,
#      34 )
#      36 trainer = SFTTrainer(
#      37         model,
#      38         train_dataset=train_dataset,
#    (...)
#      41         processing_class=tokenizer,
#      42     )
# ---> 44 trainer.train()
#      46 trainer.save_model()
#
# File /opt/venv/lib/python3.10/site-packages/transformers/trainer.py:2238, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2236         hf_hub_utils.enable_progress_bars()
#    2237 else:
# -> 2238     return inner_training_loop(
#    2239         args=args,
#    2240         resume_from_checkpoint=resume_from_checkpoint,
#    2241         trial=trial,
#    2242         ignore_keys_for_eval=ignore_keys_for_eval,
#    2243     )
#
# File /opt/venv/lib/python3.10/site-packages/transformers/trainer.py:2648, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2645     context = implicit_replication
#    2647 with context():
# -> 2648     self.optimizer.step()
#    2650 self.control = self.callback_handler.on_optimizer_step(args, self.state, self.control)
#    2652 # get leaning rate before update
#
# File /opt/venv/lib/python3.10/site-packages/accelerate/optimizer.py:179, in AcceleratedOptimizer.step(self, closure)
#     177         self._accelerate_step_called = False
#     178     else:
# --> 179         self.optimizer.step(closure)
#     180 if self.accelerator_state.distributed_type == DistributedType.XLA:
#     181     self.gradient_state.is_xla_gradients_synced = False
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:133, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     131 opt = opt_ref()
#     132 opt._opt_called = True  # type: ignore[union-attr]
# --> 133 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:516, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     511         else:
#     512             raise RuntimeError(
#     513                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     514             )
# --> 516 out = func(*args, **kwargs)
#     517 self._optimizer_step_code()
#     519 # call optimizer step post hooks
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/adam.py:237, in Adam.step(self, closure)
#     234     state_steps: list[Tensor] = []
#     235     beta1, beta2 = group["betas"]
# --> 237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#     240         grads,
#     241         exp_avgs,
#     242         exp_avg_sqs,
#     243         max_exp_avg_sqs,
#     244         state_steps,
#     245     )
#     247     adam(
#     248         params_with_grad,
#     249         grads,
#    (...)
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/adam.py:181, in Adam._init_group(self, group, params_with_grad, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps)
#     177 state["exp_avg"] = torch.zeros_like(
#     178     p, memory_format=torch.preserve_format
#     179 )
#     180 # Exponential moving average of squared gradient values
# --> 181 state["exp_avg_sq"] = torch.zeros_like(
#     182     p, memory_format=torch.preserve_format
#     183 )
#     184 if group["amsgrad"]:
#     185     # Maintains max of all exp. moving avg. of sq. grad. values
#     186     state["max_exp_avg_sq"] = torch.zeros_like(
#     187         p, memory_format=torch.preserve_format
#     188     )
#
# OutOfMemoryError: HIP out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 191.69 GiB of which 0 bytes is free. Of the allocated memory 180.17 GiB is allocated by PyTorch, and 10.43 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
